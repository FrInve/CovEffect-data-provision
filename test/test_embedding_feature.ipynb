# %%
# !pwd
# Out:
# /home/frinve/Code/CovEffect-data-provision/test

# %%
import pandas as pd

# %%
pd.read_parquet('../products/embeddings/embeddings_100.parquet')
# Out:
#                 0          1         2         3          4          5  \
# 385      7.268553   2.813714  8.464701  1.702190   3.228426  -0.911511
# 515     11.030001   3.699354 -6.042419  6.048959   6.713898   0.211823
# 1602     3.790383   9.034142 -5.555579  6.824696   4.811217  -5.744972
# 1706     7.136991  -1.047125 -4.389881  4.741620   1.259067   0.817934
# 2521    15.137749  -0.820162 -5.480362 -2.648481  -1.966862   1.732323
# ...           ...        ...       ...       ...        ...        ...
# 193556  -0.783756  -0.514936  8.900856 -6.295956  16.066191   5.735964
# 194913  11.837577  -0.137740 -7.159297  5.238410   4.530077   1.770037
# 196148  10.634830  -0.644598  0.281792  1.578146   4.145169   0.416442
# 196569  -2.124339  13.011629  4.008843 -5.255802   5.783856  11.981086
# 199347  -7.019605  14.531112  9.876776  1.016604   1.180872   8.168441
#
#                 6         7         8         9  ...        91        92  \
# ...
